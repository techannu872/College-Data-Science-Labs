# %% [markdown]
# ## **Importing all Required Libraries of Python**

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Loading Dataset into pandas datafram**

# %%
data = pd.read_csv('/content/student_exam_data.csv')

# %%
data
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0       4.370861            81.889703          0
# 1       9.556429            72.165782          1
# 2       7.587945            58.571657          0
# 3       6.387926            88.827701          1
# 4       2.404168            81.083870          0
# ..           ...                  ...        ...
# 495     4.180170            45.494924          0
# 496     6.252905            95.038815          1
# 497     1.699612            48.209118          0
# 498     9.769553            97.014241          1
# 499     9.875897            66.760346          1
#
# [500 rows x 3 columns]

# %% [markdown]
# ## **Reading and Visualizing the data's features' datatypes and values**

# %%
data.describe() #It gives the count, mean, max values etc
# Out:
#        Study Hours  Previous Exam Score   Pass/Fail
# count   500.000000           500.000000  500.000000
# mean      5.487055            68.917084    0.368000
# std       2.688196            17.129607    0.482744
# min       1.045554            40.277921    0.000000
# 25%       3.171517            53.745955    0.000000
# 50%       5.618474            68.309294    0.000000
# 75%       7.805124            83.580209    1.000000
# max       9.936683            99.983060    1.000000

# %%
data.info() #it tells the no. of values and its datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Study Hours          500 non-null    float64
#  1   Previous Exam Score  500 non-null    float64
#  2   Pass/Fail            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %% [markdown]
# ## **Checking the presence of Missing values and  NA bys using 'isnull() and 'isna'**

# %%
data.isnull() #Since all values are fALSE that means there are no missing values
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0          False                False      False
# 1          False                False      False
# 2          False                False      False
# 3          False                False      False
# 4          False                False      False
# ..           ...                  ...        ...
# 495        False                False      False
# 496        False                False      False
# 497        False                False      False
# 498        False                False      False
# 499        False                False      False
#
# [500 rows x 3 columns]

# %%
data.isna() #Since all values are fALSE that means there are no missing values
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0          False                False      False
# 1          False                False      False
# 2          False                False      False
# 3          False                False      False
# 4          False                False      False
# ..           ...                  ...        ...
# 495        False                False      False
# 496        False                False      False
# 497        False                False      False
# 498        False                False      False
# 499        False                False      False
#
# [500 rows x 3 columns]

# %% [markdown]
# ## **Checking the size of data**

# %%
data.shape #it shows that there are 500 rows and 3 columns
# Out:
# (500, 3)
